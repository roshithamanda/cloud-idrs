# %%
from google.colab import drive
drive.mount('/content/drive')

# Create your project folders in Drive
# !mkdir -p /content/drive/MyDrive/CIDRS/data
# !mkdir -p /content/drive/MyDrive/CIDRS/models
# !mkdir -p /content/drive/MyDrive/CIDRS/notebooks

print("✅ Colab ready! Drive mounted at: /content/drive/MyDrive/CIDRS")
# Out:
# Mounted at /content/drive
# ✅ Colab ready! Drive mounted at: /content/drive/MyDrive/CIDRS

# %%
# !pip install scikit-learn tensorflow pandas numpy matplotlib seaborn imbalanced-learn joblib

# %%
import sklearn
import tensorflow as tf
import pandas as pd
import numpy as np

print(f"Scikit-learn: {sklearn.__version__}")
print(f"TensorFlow: {tf.__version__}")
print(f"GPU Available: {tf.config.list_physical_devices('GPU')}")
print(f"Pandas: {pd.__version__}")
print("✅ All packages installed successfully!")
# Out:
# Scikit-learn: 1.6.1
# TensorFlow: 2.19.0
# GPU Available: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Pandas: 2.2.2
# ✅ All packages installed successfully!
